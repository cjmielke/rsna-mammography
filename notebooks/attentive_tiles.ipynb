# %%
import seaborn as sns
import pandas as pd

# %%
tiles = pd.read_feather('/fast/rsna-breast/tables/attn_scores_all_giddy_rain.feather')

# %%
tileCounts = tiles.groupby('imgID').size()

# %%
tileCounts
# Out:
# imgID
# 68491          48
# 83977          88
# 127964        198
# 193459        101
# 225973         83
#              ...
# 2147266534    123
# 2147293172    137
# 2147355367     90
# 2147415608     56
# 2147471846     85
# Length: 54706, dtype: int64

# %%
images = tiles[['ptID', 'imgID']].drop_duplicates()

# %%
sns.histplot(tileCounts)
# Out:
# <AxesSubplot: ylabel='Count'>
