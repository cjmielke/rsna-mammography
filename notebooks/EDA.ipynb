# %%
import seaborn as sns
import pandas as pd

# %%
labels = pd.read_csv('/fast/rsna-breast/train.csv')

# %%
sns.violinplot(data=labels, x='cancer', y='age')
# Out:
# <AxesSubplot: xlabel='cancer', ylabel='age'>

# %%
sns.violinplot(data=labels, x='cancer', y='age', hue='laterality')
# Out:
# <AxesSubplot: xlabel='cancer', ylabel='age'>

# %%
sns.violinplot(data=labels, x='cancer', y='age', hue='biopsy')
# Out:
# <AxesSubplot: xlabel='cancer', ylabel='age'>

# %%
sns.violinplot(data=labels, x='cancer', y='age', )
# Out:
# <AxesSubplot: xlabel='cancer', ylabel='age'>

# %%
sns.violinplot(data=labels, x='cancer', y='age', hue='density')
# Out:
# <AxesSubplot: xlabel='cancer', ylabel='age'>

# %%
labels
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0            2       10006   462822612          L   CC  61.0       0       0
# 1            2       10006  1459541791          L  MLO  61.0       0       0
# 2            2       10006  1864590858          R  MLO  61.0       0       0
# 3            2       10006  1874946579          R   CC  61.0       0       0
# 4            2       10011   220375232          L   CC  55.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 54701        1        9973  1729524723          R  MLO  43.0       0       0
# 54702        1        9989    63473691          L  MLO  60.0       0       0
# 54703        1        9989  1078943060          L   CC  60.0       0       0
# 54704        1        9989   398038886          R  MLO  60.0       0       0
# 54705        1        9989   439796429          R   CC  60.0       0       0
#
# ...

# %%
cancer=labels[labels.cancer==1]
cancer
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 87           1       10130   388811999          L  MLO  71.0       1       1
# 88           1       10130   613462606          L   CC  71.0       1       1
# 89           1       10130  1360338805          L   CC  71.0       1       1
# 90           1       10130  1672636630          L  MLO  71.0       1       1
# 190          1       10226   461614796          L  MLO  71.0       1       1
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 54485        2        9707  1900919592          R  MLO  56.0       1       1
# 54593        2        9840   111786935          R  MLO  59.0       1       1
# 54594        2        9840  1559360810          R   CC  59.0       1       1
# 54595        2        9851  1409270544          L  MLO  58.0       1       1
# 54596        2        9851  1434430689          L   CC  58.0       1       1
#
# ...

# %%
patientsNoCancer = set(labels[labels.cancer==0].patient_id)
cancer[cancer.patient_id.isin(patientsNoCancer)]
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 87           1       10130   388811999          L  MLO  71.0       1       1
# 88           1       10130   613462606          L   CC  71.0       1       1
# 89           1       10130  1360338805          L   CC  71.0       1       1
# 90           1       10130  1672636630          L  MLO  71.0       1       1
# 190          1       10226   461614796          L  MLO  71.0       1       1
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 54485        2        9707  1900919592          R  MLO  56.0       1       1
# 54593        2        9840   111786935          R  MLO  59.0       1       1
# 54594        2        9840  1559360810          R   CC  59.0       1       1
# 54595        2        9851  1409270544          L  MLO  58.0       1       1
# 54596        2        9851  1434430689          L   CC  58.0       1       1
#
# ...

# %%
cancer.shape
# Out:
# (1158, 14)

# %%
labels[labels.patient_id==10130]
# Out:
#     site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 87        1       10130   388811999          L  MLO  71.0       1       1
# 88        1       10130   613462606          L   CC  71.0       1       1
# 89        1       10130  1360338805          L   CC  71.0       1       1
# 90        1       10130  1672636630          L  MLO  71.0       1       1
# 91        1       10130  1013166704          R   CC  71.0       0       0
# 92        1       10130  1165309236          R   CC  71.0       0       0
# 93        1       10130  2110820077          R  MLO  71.0       0       0
#
#     invasive  BIRADS  implant density  machine_id  difficult_negative_case
# 87         1     0.0        0       B          49                    False
# 88         1     0.0        0       B          49                    False
# 89         1     0.0        0       B          49                    False
# 90         1     0.0        0       B          49                    False
# ...

# %%
labels[labels.patient_id==9707]
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 54482        2        9707   337700893          L  MLO  56.0       0       0
# 54483        2        9707   394053487          L   CC  56.0       0       0
# 54484        2        9707  1590470368          R   CC  56.0       1       1
# 54485        2        9707  1900919592          R  MLO  56.0       1       1
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case
# 54482         0     NaN        0     NaN          21                    False
# 54483         0     NaN        0     NaN          21                    False
# 54484         1     NaN        0     NaN          21                    False
# 54485         1     NaN        0     NaN          21                    False

# %%
labels['patient_id'].value_counts().head(59)
# Out:
# 52868    14
# 55706    14
# 9795     13
# 51115    13
# 5421     13
# 26530    13
# 44047    13
# 56608    12
# 51028    12
# 12922    12
# 26549    12
# 55783    12
# 47003    12
# 3280     12
# 46422    12
# 44351    12
# 57468    12
# 26832    12
# 26515    12
# 35145    11
# 46268    11
# 10442    11
# 9088     11
# 45945    11
# 43230    11
# 23334    11
# 17845    11
# 23520    11
# 45260    11
# 17704    11
# 59137    11
# 38944    11
# 53530    11
# 4098     11
# 4659     11
# 21121    11
# 2810     11
# 8421     11
# 13095    10
# 21744    10
# 32985    10
# 37298    10
# 3313     10
# 4021     10
# 63138    10
# 10847    10
# 57989    10
# 8619     10
# 33581    10
# 13211    10
# 15573    10
# 47542    10
# 2111     10
# 55724    10
# 17582    10
# 63527    10
# 45127    10
# 2516     10
# 34189    10
# Name: patient_id, dtype: int64

# %%
labels[labels.patient_id==44047]
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 31754        1       44047    40147212          L  MLO  48.0       0       0
# 31755        1       44047   822072941          L  MLO  48.0       0       0
# 31756        1       44047   855155693          L   CC  48.0       0       0
# 31757        1       44047  1113266761          L  MLO  48.0       0       0
# 31758        1       44047  1624791783          L   CC  48.0       0       0
# 31759        1       44047  1731700724          L   CC  48.0       0       0
# 31760        1       44047    41014668          R   CC  48.0       0       0
# 31761        1       44047   409056837          R  MLO  48.0       0       0
# 31762        1       44047   432223802          R  MLO  48.0       0       0
# 31763        1       44047   541390054          R  MLO  48.0       0       0
# 31764        1       44047   627380160          R   CC  48.0       0       0
# ...

# %%
import numpy as np
np.random.rand(4)
# Out:
# array([0.68332792, 0.86257209, 0.36522858, 0.36657486])

# %%
labels['preds'] = np.random.rand(labels.shape[0])

# %%
maxPreds = labels[['patient_id','laterality','preds']].groupby(['patient_id', 'laterality']).max().reset_index()
maxPreds
# Out:
#        patient_id laterality     preds
# 0               5          L  0.092803
# 1               5          R  0.611292
# 2              25          L  0.370140
# 3              25          R  0.731209
# 4              28          L  0.980659
# ...           ...        ...       ...
# 23821       65526          R  0.044837
# 23822       65530          L  0.559373
# 23823       65530          R  0.759527
# 23824       65534          L  0.796290
# 23825       65534          R  0.970612
#
# [23826 rows x 3 columns]

# %%
labels[labels.patient_id==5]
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 37282        2           5   640805896          L  MLO  68.0       0       0
# 37283        2           5  1351088028          L   CC  68.0       0       0
# 37284        2           5   940388076          R   CC  68.0       0       0
# 37285        2           5  1633417959          R  MLO  68.0       0       0
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case  \
# 37282         0     0.0        0     NaN          21                     True
# 37283         0     0.0        0     NaN          21                     True
# 37284         0     NaN        0     NaN          21                    False
# 37285         0     NaN        0     NaN          21                    False
#
#           preds
# 37282  0.092803
# 37283  0.048522
# 37284  0.611292
# 37285  0.544776

# %%
M = labels.set_index(['patient_id'])
